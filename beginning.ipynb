# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import yfinance as yf

# %%
from sklearn.datasets import load_iris
from sklearn.decomposition import PCA

# %%
adbe = 'ADBE'

# %%
adbe_df = yf.download(adbe)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
adbe_df['Returns'] = adbe_df["Adj Close"].pct_change()

# %%
adbe_df.drop(["Open","High", "Low", "Close", "Adj Close", "Volume"], axis=1, inplace=True)

# %%
adbe_df
# Out:
#              Returns
# Date
# 1986-08-13       NaN
# 1986-08-14  0.055552
# 1986-08-15 -0.017543
# 1986-08-18 -0.035712
# 1986-08-19  0.018517
# ...              ...
# 2022-06-17 -0.011751
# 2022-06-21  0.006098
# 2022-06-22  0.006446
# 2022-06-23  0.030958
# 2022-06-24  0.029418
#
# [9040 rows x 1 columns]

# %%
adbe_df = adbe_df.reset_index(drop=True)

adbe_df
# Out:
#        Returns
# 0          NaN
# 1     0.055552
# 2    -0.017543
# 3    -0.035712
# 4     0.018517
# ...        ...
# 9035 -0.011751
# 9036  0.006098
# 9037  0.006446
# 9038  0.030958
# 9039  0.029418
#
# [9040 rows x 1 columns]

# %%
iris = load_iris()

# %%
target_species = iris.target

# %%
x_reduced = PCA(n_components=3).fit_transform(iris.data)

# %%
fig = plt.figure()
axes = Axes3D(fig)
axes.set_title("Iris Dataset by PCA", size=14)
axes.set_xlabel("First eigenvector")
axes.set_ylabel("Second eigenvector")
axes.set_zlabel("Third eigenvector")
axes.w_xaxis.set_ticklabels(())
axes.w_yaxis.set_ticklabels(())
axes.w_zaxis.set_ticklabels(())
axes.scatter(x_reduced[:,0],x_reduced[:,1],x_reduced[:,2], c=target_species)
# Out:
# /var/folders/_w/nqnyx74s6hbb0p5hvj6czdy00000gn/T/ipykernel_34654/2114717630.py:2: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   axes = Axes3D(fig)

# %%
# imports from matplotlib import pyplot as plt
from matplotlib import pyplot as plt
import pylab
from mpl_toolkits.mplot3d import Axes3D
from mpl_toolkits.mplot3d import proj3d
# %matplotlib inline
# %pylab inline

from sklearn.manifold import TSNE
from sklearn.decomposition import PCA





#TSNE(3)
data = TSNE(n_components=3, random_state=0).fit_transform(x_reduced)
x, y, z = list(zip(*data))

fig = pylab.figure()
ax = fig.add_subplot(111, projection = '3d')
sc = ax.scatter(x, y, z)
# Out:
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib
# /Users/tylersear/opt/anaconda3/lib/python3.9/site-packages/IPython/core/magics/pylab.py:162: UserWarning: pylab import has clobbered these variables: ['pylab', 'axes']
# `%matplotlib` prevents importing * from pylab and numpy
#   warn("pylab import has clobbered these variables: %s"  % clobbered +
# /Users/tylersear/opt/anaconda3/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:795: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /Users/tylersear/opt/anaconda3/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:805: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
