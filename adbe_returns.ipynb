# %%
import yfinance as yf
import pandas as pd
import numpy as np

# %%
# get ticker info
adbe = 'ADBE'

# %%
adbe_df = yf.download(adbe)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
adbe_df['Returns'] = adbe_df["Adj Close"].pct_change()

# %%
adbe_df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 1986-08-13    0.000000    0.218750    0.210938    0.210938    0.198057
# 1986-08-14    0.000000    0.230469    0.222656    0.222656    0.209060
# 1986-08-15    0.000000    0.222656    0.218750    0.218750    0.205392
# 1986-08-18    0.000000    0.218750    0.210938    0.210938    0.198057
# 1986-08-19    0.000000    0.218750    0.214844    0.214844    0.201725
# ...                ...         ...         ...         ...         ...
# 2022-06-17  349.239990  367.320007  338.000000  360.790009  360.790009
# 2022-06-21  355.019989  372.799988  353.510010  362.989990  362.989990
# 2022-06-22  360.790009  372.549988  358.220001  365.329987  365.329987
# 2022-06-23  371.709991  378.179993  367.470001  376.640015  376.640015
# 2022-06-24  380.640015  388.059998  378.220001  387.720001  387.720001
#
#               Volume   Returns
# Date
# 1986-08-13  18899200       NaN
# 1986-08-14   4160000  0.055552
# 1986-08-15   4332800 -0.017543
# 1986-08-18   2828800 -0.035712
# 1986-08-19   2060800  0.018517
# ...              ...       ...
# 2022-06-17   9455900 -0.011751
# 2022-06-21   5343500  0.006098
# 2022-06-22   3168200  0.006446
# 2022-06-23   2534300  0.030958
# 2022-06-24   3303400  0.029418
#
# [9040 rows x 7 columns]

# %%
adbe_df.drop(["Open","High", "Low", "Close", "Adj Close", "Volume"], axis=1, inplace=True)

adbe_df
# Out:
#              Returns
# Date
# 1986-08-13       NaN
# 1986-08-14  0.055552
# 1986-08-15 -0.017543
# 1986-08-18 -0.035712
# 1986-08-19  0.018517
# ...              ...
# 2022-06-17 -0.011751
# 2022-06-21  0.006098
# 2022-06-22  0.006446
# 2022-06-23  0.030958
# 2022-06-24  0.029418
#
# [9040 rows x 1 columns]

# %%
# Out:
# 'ADBE'
